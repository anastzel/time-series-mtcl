# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pmdarima
#   Downloading pmdarima-2.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 23.2 MB/s eta 0:00:00
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (0.29.33)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.7.3)
# Collecting statsmodels>=0.13.2
#   Downloading statsmodels-0.13.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 83.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.3.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19->pmdarima) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.15.0)
# Installing collected packages: statsmodels, pmdarima
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.12.2
#     Uninstalling statsmodels-0.12.2:
#       Successfully uninstalled statsmodels-0.12.2
# Successfully installed pmdarima-2.0.2 statsmodels-0.13.5

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
import math

import torch
from torch import nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from tqdm import tqdm

import pmdarima.arima as pmd
from pmdarima import model_selection
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.api import qqplot
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error, mean_absolute_error

from pmdarima import auto_arima
import warnings
warnings.filterwarnings("ignore")

# %%
# Copy the dataset.zip and unzip it
# !cp "/content/drive/MyDrive/Microchip/dataset.zip" "/content"
# !unzip dataset.zip
# Out:
# Archive:  dataset.zip
#   inflating: dataset/pcb_1.jpg
#   inflating: dataset/pcb_2.jpg
#   inflating: dataset/pcb_3.jpg
#   inflating: dataset/pcb_4.jpg
#   inflating: dataset/pcb_5.jpg
#   inflating: dataset/pcb_6.jpg
#    creating: dataset/typeA/
#    creating: dataset/typeA/test/
#   inflating: dataset/typeA/test/annotations.csv
#    creating: dataset/typeA/train/
#   inflating: dataset/typeA/train/annotations.csv
#    creating: dataset/typeB/
#    creating: dataset/typeB/test/
#   inflating: dataset/typeB/test/annotations.csv
#    creating: dataset/typeB/train/
#   inflating: dataset/typeB/train/annotations.csv
#    creating: dataset/typeC/
#    creating: dataset/typeC/test/
#   inflating: dataset/typeC/test/annotations.csv
#    creating: dataset/typeC/train/
#   inflating: dataset/typeC/train/annotations.csv
#    creating: dataset/typeD/
#    creating: dataset/typeD/test/
#   inflating: dataset/typeD/test/annotations.csv
#    creating: dataset/typeD/train/
#   inflating: dataset/typeD/train/annotations.csv
#    creating: dataset/typeE/
#    creating: dataset/typeE/test/
#   inflating: dataset/typeE/test/annotations.csv
#    creating: dataset/typeE/train/
#   inflating: dataset/typeE/train/annotations.csv

# %%
def load_dataset(filename):
    # Read the .csv
    df = pd.read_csv(filename, delimiter=';')
    # Drop columns that we don't need
    df_cleaned = df.drop(df.columns[[0, 1, 2, 3]],axis = 1)
    # Set Dataframe's dtype to float32
    df_cleaned = df_cleaned.astype(np.float32)

    return df_cleaned

# %%
types = ['typeA', 'typeB', 'typeC', 'typeD', 'typeE']

# %%
from statsmodels.tsa.stattools import adfuller

def ad_test(dataset):
    dftest = adfuller(dataset, autolag = 'AIC')
    print(f"\n1.ADF: {dftest[0]}")
    print(f"2.P-Value: {dftest[1]}")
    print(f"3.Num of Lags: {dftest[2]}")
    print(f"4.Num of observations used for ADF Regression and Critical values calculation: {dftest[3]}")
    print(f"5.Critical values: {dftest[4]}")
    for key, val in dftest[4].items():
        print(f"\t{key}: {val}")
    print()

# %%
for type in types:
    # Define train csv filename
    train_filename = f"/content/dataset/{type}/train/annotations.csv"
    test_filename = f"/content/dataset/{type}/test/annotations.csv"

    print(f"\nPerforming time series analysis for {type}\n")

    train_df = load_dataset(train_filename)
    test_df = load_dataset(test_filename)

    feature_types = ['50um', '20um']

    # with open(f"tsa_logs.txt",'w',encoding = 'utf-8') as f:
    for feature in feature_types:
        
        print(f"\n ############## {feature} ##############\n")

        # plt.figure(figsize=(12,5))
        # plt.plot(train_df.index, train_df[feature])
        # plt.show()

        ad_test(train_df[feature])

        # split into training and testing data
        # to_row = int(len(df_cleaned)*0.9)
        # training_data, testing_data = model_selection.train_test_split(df_cleaned[feature], train_size=int(9 * df_cleaned[feature].shape[0] / 10))

        training_data, testing_data = train_df[feature], test_df[feature]

        # sm.graphics.tsa.plot_acf(training_data, zero=False)
        # plt.title(f"Autocorrelation for {feature}")        
        # plt.show()

        # sm.graphics.tsa.plot_pacf(training_data, zero=False)
        # plt.title(f"Partial Autocorrelation for {feature}")        
        # plt.show()

        model = auto_arima(training_data, max_p=15, max_q=15, trace=True, supress_warnings=True)
        print(model.summary())
# Out:
# Performing time series analysis for typeA
#
#
#  ############## 50um ##############
#
#
# 1.ADF: -2.3994342989939175
# 2.P-Value: 0.14189613727866313
# 3.Num of Lags: 2
# 4.Num of observations used for ADF Regression and Critical values calculation: 294
# 5.Critical values: {'1%': -3.452789844280995, '5%': -2.871421512222641, '10%': -2.5720351510944512}
# 	1%: -3.452789844280995
# 	5%: -2.871421512222641
# 	10%: -2.5720351510944512
#
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-6473.222, Time=0.33 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-6481.221, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-6478.900, Time=0.16 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-6341.854, Time=0.31 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-7013.735, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-6254.431, Time=0.44 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.417 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  297
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                3507.867
# Date:                Thu, 26 Jan 2023   AIC                          -7013.735
# Time:                        15:44:16   BIC                          -7010.045
# Sample:                             0   HQIC                         -7012.257
#                                 - 297
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      7.471e-12   1.11e-10      0.067      0.946    -2.1e-10    2.25e-10
# ===================================================================================
# Ljung-Box (L1) (Q):                  10.49   Jarque-Bera (JB):              2487.13
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.87   Skew:                            -1.90
# Prob(H) (two-sided):                  0.48   Kurtosis:                        16.69
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#  ############## 20um ##############
#
#
# 1.ADF: -3.9399998347516423
# 2.P-Value: 0.001759416519315573
# 3.Num of Lags: 0
# 4.Num of observations used for ADF Regression and Critical values calculation: 296
# 5.Critical values: {'1%': -3.452636878592149, '5%': -2.8713543954331433, '10%': -2.5719993576515705}
# 	1%: -3.452636878592149
# 	5%: -2.8713543954331433
# 	10%: -2.5719993576515705
#
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-6473.222, Time=0.46 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-6481.221, Time=0.17 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-6479.015, Time=0.17 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-6319.198, Time=0.18 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-7013.735, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-6432.741, Time=0.33 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.355 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  297
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                3507.867
# Date:                Thu, 26 Jan 2023   AIC                          -7013.735
# Time:                        15:44:17   BIC                          -7010.045
# Sample:                             0   HQIC                         -7012.257
#                                 - 297
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      7.471e-12   1.11e-10      0.067      0.946    -2.1e-10    2.25e-10
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.66   Jarque-Bera (JB):              7784.73
# Prob(Q):                              0.06   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.53   Skew:                             3.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                        27.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Performing time series analysis for typeB
#
#
#  ############## 50um ##############
#
#
# 1.ADF: -3.640075809102227
# 2.P-Value: 0.005039499284453506
# 3.Num of Lags: 2
# 4.Num of observations used for ADF Regression and Critical values calculation: 294
# 5.Critical values: {'1%': -3.452789844280995, '5%': -2.871421512222641, '10%': -2.5720351510944512}
# 	1%: -3.452789844280995
# 	5%: -2.871421512222641
# 	10%: -2.5720351510944512
#
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-6379.223, Time=0.51 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-6314.948, Time=0.15 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-6438.131, Time=0.22 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-6570.843, Time=0.23 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-6290.828, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-6367.189, Time=0.32 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=-6284.473, Time=0.19 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-6377.961, Time=0.76 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-7630.208, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-7607.233, Time=0.09 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=-7569.932, Time=0.15 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-7652.354, Time=0.10 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-7603.342, Time=0.08 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-7594.267, Time=0.11 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 3.054 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  297
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                3828.177
# Date:                Thu, 26 Jan 2023   AIC                          -7652.354
# Time:                        15:44:20   BIC                          -7644.966
# Sample:                             0   HQIC                         -7649.396
#                                 - 297
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9394   5.63e-21   1.67e+20      0.000       0.939       0.939
# sigma2      1.007e-12    1.1e-10      0.009      0.993   -2.15e-10    2.17e-10
# ===================================================================================
# Ljung-Box (L1) (Q):                  24.47   Jarque-Bera (JB):               205.20
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.63   Skew:                            -0.02
# Prob(H) (two-sided):                  0.02   Kurtosis:                         7.07
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number    inf. Standard errors may be unstable.
#
#  ############## 20um ##############
#
#
# 1.ADF: -3.2859947234670877
# 2.P-Value: 0.015516236227684815
# 3.Num of Lags: 2
# 4.Num of observations used for ADF Regression and Critical values calculation: 294
# 5.Critical values: {'1%': -3.452789844280995, '5%': -2.871421512222641, '10%': -2.5720351510944512}
# 	1%: -3.452789844280995
# 	5%: -2.871421512222641
# 	10%: -2.5720351510944512
#
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-6637.606, Time=0.48 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-6481.221, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-6460.561, Time=0.16 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-6254.258, Time=0.32 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-7013.735, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-6308.223, Time=0.42 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.598 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  297
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                3507.868
# Date:                Thu, 26 Jan 2023   AIC                          -7013.735
# Time:                        15:44:22   BIC                          -7010.045
# Sample:                             0   HQIC                         -7012.258
#                                 - 297
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      7.471e-12   1.11e-10      0.067      0.946    -2.1e-10    2.25e-10
# ===================================================================================
# Ljung-Box (L1) (Q):                  49.88   Jarque-Bera (JB):               209.94
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.61   Skew:                             0.97
# Prob(H) (two-sided):                  0.02   Kurtosis:                         6.65
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Performing time series analysis for typeC
#
#
#  ############## 50um ##############
#
#
# 1.ADF: -2.974529999811914
# 2.P-Value: 0.037342413762483796
# 3.Num of Lags: 4
# 4.Num of observations used for ADF Regression and Critical values calculation: 292
# 5.Critical values: {'1%': -3.4529449243622383, '5%': -2.871489553425686, '10%': -2.572071437887033}
# 	1%: -3.4529449243622383
# 	5%: -2.871489553425686
# 	10%: -2.572071437887033
#
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-6537.557, Time=0.44 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-6481.221, Time=0.17 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-6476.231, Time=0.16 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-6320.145, Time=0.35 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-7013.735, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-6313.561, Time=0.45 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.623 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  297
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                3507.868
# Date:                Thu, 26 Jan 2023   AIC                          -7013.735
# Time:                        15:44:24   BIC                          -7010.045
# Sample:                             0   HQIC                         -7012.257
#                                 - 297
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      7.471e-12   1.11e-10      0.067      0.946    -2.1e-10    2.25e-10
# ===================================================================================
# Ljung-Box (L1) (Q):                  27.43   Jarque-Bera (JB):               891.85
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.74   Skew:                            -0.87
# Prob(H) (two-sided):                  0.13   Kurtosis:                        11.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#  ############## 20um ##############
#
#
# 1.ADF: -4.121768027735077
# 2.P-Value: 0.0008913215379513056
# 3.Num of Lags: 0
# 4.Num of observations used for ADF Regression and Critical values calculation: 296
# 5.Critical values: {'1%': -3.452636878592149, '5%': -2.8713543954331433, '10%': -2.5719993576515705}
# 	1%: -3.452636878592149
# 	5%: -2.8713543954331433
# 	10%: -2.5719993576515705
#
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-6599.908, Time=0.41 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-6481.221, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-6478.944, Time=0.17 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-6278.789, Time=0.24 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-7013.735, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-6295.289, Time=0.34 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.334 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  297
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                3507.868
# Date:                Thu, 26 Jan 2023   AIC                          -7013.735
# Time:                        15:44:25   BIC                          -7010.045
# Sample:                             0   HQIC                         -7012.257
#                                 - 297
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      7.471e-12   1.11e-10      0.067      0.946    -2.1e-10    2.25e-10
# ===================================================================================
# Ljung-Box (L1) (Q):                   4.90   Jarque-Bera (JB):              6465.95
# Prob(Q):                              0.03   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.65   Skew:                             2.51
# Prob(H) (two-sided):                  0.03   Kurtosis:                        25.34
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Performing time series analysis for typeD
#
#
#  ############## 50um ##############
#
#
# 1.ADF: -3.892097332807579
# 2.P-Value: 0.0020937823161691228
# 3.Num of Lags: 2
# 4.Num of observations used for ADF Regression and Critical values calculation: 294
# 5.Critical values: {'1%': -3.452789844280995, '5%': -2.871421512222641, '10%': -2.5720351510944512}
# 	1%: -3.452789844280995
# 	5%: -2.871421512222641
# 	10%: -2.5720351510944512
#
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-6319.364, Time=0.71 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-6314.948, Time=0.14 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-6300.344, Time=0.15 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-6660.644, Time=0.23 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-6290.828, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-6285.246, Time=0.40 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=-6587.437, Time=0.53 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-6296.175, Time=0.61 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-6280.441, Time=0.07 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0] intercept
# Total fit time: 2.889 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  297
# Model:               SARIMAX(0, 0, 1)   Log Likelihood                3333.322
# Date:                Thu, 26 Jan 2023   AIC                          -6660.644
# Time:                        15:44:28   BIC                          -6649.562
# Sample:                             0   HQIC                         -6656.207
#                                 - 297
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -3.708e-06   1.25e-05     -0.297      0.767   -2.82e-05    2.08e-05
# ma.L1          0.1489   1.33e-10   1.12e+09      0.000       0.149       0.149
# sigma2      1.033e-11   6.52e-09      0.002      0.999   -1.28e-08    1.28e-08
# ===================================================================================
# Ljung-Box (L1) (Q):                   5.76   Jarque-Bera (JB):            958943.75
# Prob(Q):                              0.02   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.00   Skew:                            16.40
# Prob(H) (two-sided):                  0.99   Kurtosis:                       279.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.61e+25. Standard errors may be unstable.
#
#  ############## 20um ##############
#
#
# 1.ADF: -3.6846886653876987
# 2.P-Value: 0.0043337495988925185
# 3.Num of Lags: 2
# 4.Num of observations used for ADF Regression and Critical values calculation: 294
# 5.Critical values: {'1%': -3.452789844280995, '5%': -2.871421512222641, '10%': -2.5720351510944512}
# 	1%: -3.452789844280995
# 	5%: -2.871421512222641
# 	10%: -2.5720351510944512
#
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-6413.357, Time=0.74 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-6314.948, Time=0.15 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-6294.631, Time=0.13 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-6602.022, Time=0.17 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-6290.828, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-6320.007, Time=0.55 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=-7034.707, Time=0.32 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-6346.822, Time=0.71 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=-6282.300, Time=0.24 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=-6334.025, Time=0.74 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=-7594.061, Time=0.15 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-6275.608, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=-7623.837, Time=0.18 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-7607.555, Time=0.14 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=-7631.889, Time=0.23 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-7648.190, Time=0.15 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-7633.006, Time=0.08 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=-7636.736, Time=0.22 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-7651.690, Time=0.24 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 5.322 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  297
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                3827.845
# Date:                Thu, 26 Jan 2023   AIC                          -7651.690
# Time:                        15:44:33   BIC                          -7644.302
# Sample:                             0   HQIC                         -7648.732
#                                 - 297
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9557   7.76e-21   1.23e+20      0.000       0.956       0.956
# sigma2      1.008e-12    1.1e-10      0.009      0.993   -2.15e-10    2.17e-10
# ===================================================================================
# Ljung-Box (L1) (Q):                  48.36   Jarque-Bera (JB):              1899.52
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.55   Skew:                            -0.23
# Prob(H) (two-sided):                  0.00   Kurtosis:                        15.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.14e+26. Standard errors may be unstable.
#
# Performing time series analysis for typeE
#
#
#  ############## 50um ##############
#
#
# 1.ADF: -2.0883671439016074
# 2.P-Value: 0.24921788578615078
# 3.Num of Lags: 5
# 4.Num of observations used for ADF Regression and Critical values calculation: 291
# 5.Critical values: {'1%': -3.4530232710482367, '5%': -2.871523926671883, '10%': -2.5720897694878424}
# 	1%: -3.4530232710482367
# 	5%: -2.871523926671883
# 	10%: -2.5720897694878424
#
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-6280.120, Time=0.71 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-6481.221, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-6465.226, Time=0.17 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-6250.562, Time=0.52 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-7013.735, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-6249.292, Time=0.59 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 2.214 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  297
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                3507.868
# Date:                Thu, 26 Jan 2023   AIC                          -7013.735
# Time:                        15:44:35   BIC                          -7010.045
# Sample:                             0   HQIC                         -7012.258
#                                 - 297
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      7.471e-12   1.11e-10      0.067      0.946    -2.1e-10    2.25e-10
# ===================================================================================
# Ljung-Box (L1) (Q):                  47.53   Jarque-Bera (JB):                98.25
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.88   Skew:                            -0.18
# Prob(H) (two-sided):                  0.53   Kurtosis:                         5.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
#  ############## 20um ##############
#
#
# 1.ADF: -2.993065203316305
# 2.P-Value: 0.03554711788504695
# 3.Num of Lags: 6
# 4.Num of observations used for ADF Regression and Critical values calculation: 290
# 5.Critical values: {'1%': -3.453102162983312, '5%': -2.871558538275452, '10%': -2.5721082282996433}
# 	1%: -3.453102162983312
# 	5%: -2.871558538275452
# 	10%: -2.5721082282996433
#
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-6550.032, Time=0.39 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-6481.221, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-6466.863, Time=0.16 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-6256.558, Time=0.37 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-7013.735, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-6252.468, Time=0.39 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.518 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  297
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                3507.868
# Date:                Thu, 26 Jan 2023   AIC                          -7013.735
# Time:                        15:44:37   BIC                          -7010.045
# Sample:                             0   HQIC                         -7012.258
#                                 - 297
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      7.471e-12   1.11e-10      0.067      0.946    -2.1e-10    2.25e-10
# ===================================================================================
# Ljung-Box (L1) (Q):                  45.75   Jarque-Bera (JB):                82.63
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.83   Skew:                             0.72
# Prob(H) (two-sided):                  0.37   Kurtosis:                         5.16
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
